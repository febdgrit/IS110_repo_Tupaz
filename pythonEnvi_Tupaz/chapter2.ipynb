# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/ColabNotebooks/IS110_Bperformance_Tupaz/pythonEnvi_Tupaz
# Out:
# /content/drive/MyDrive/ColabNotebooks/IS110_Bperformance_Tupaz/pythonEnvi_Tupaz

# %%
# !pwd
#for the working directory
# Out:
# /content/drive/MyDrive/ColabNotebooks/IS110_Bperformance_Tupaz/pythonEnvi_Tupaz

# %%
# !pip install virtualenv
# Out:
# Collecting virtualenv
#   Downloading virtualenv-20.38.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting distlib<1,>=0.3.7 (from virtualenv)
#   Downloading distlib-0.4.0-py2.py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: filelock<4,>=3.24.2 in /usr/local/lib/python3.12/dist-packages (from virtualenv) (3.24.2)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /usr/local/lib/python3.12/dist-packages (from virtualenv) (4.9.2)
# Downloading virtualenv-20.38.0-py3-none-any.whl (5.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 51.5 MB/s eta 0:00:00
# Downloading distlib-0.4.0-py2.py3-none-any.whl (469 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 29.6 MB/s eta 0:00:00
# Installing collected packages: distlib, virtualenv
# Successfully installed distlib-0.4.0 virtualenv-20.38.0

# %%
# !virtualenv feb
# Out:
# created virtual environment CPython3.12.12.final.0-64 in 8393ms
#   creator CPython3Posix(dest=/content/drive/MyDrive/ColabNotebooks/IS110_Bperformance_Tupaz/pythonEnvi_Tupaz/feb, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, via=copy, app_data_dir=/root/.cache/virtualenv)
#     added seed packages: pip==26.0.1
#   activators BashActivator,CShellActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator

# %%
# !source feb/bin/activate

# %%
# %%writefile chapter2.txt
# pandas
# numpy
# Out:
# Writing chapter2.txt

# %%
#install the packages in the requirements.txt
# !feb/bin/pip install -r requirements.txt
# Out:
# Collecting pandas (from -r requirements.txt (line 1))
#   Downloading pandas-3.0.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
# Collecting numpy (from -r requirements.txt (line 2))
#   Downloading numpy-2.4.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Collecting python-dateutil>=2.8.2 (from pandas->-r requirements.txt (line 1))
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting six>=1.5 (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 1))
#   Downloading six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Downloading pandas-3.0.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (10.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 97.3 MB/s  0:00:00
# Downloading numpy-2.4.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 112.4 MB/s  0:00:00
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Installing collected packages: six, numpy, python-dateutil, pandas
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [pandas]
# Successfully installed numpy-2.4.2 pandas-3.0.1 python-dateutil-2.9.0.post0 six-1.17.0

# %%
#requirements.txt has been created or updated
# !feb/bin/pip freeze > requirements.txt

# %%
# !feb/bin/pip list
# Out:
# Package         Version
# --------------- -----------
# numpy           2.4.2
# pandas          3.0.1
# pip             26.0.1
# python-dateutil 2.9.0.post0
# six             1.17.0

# %%
# !cat requirements.txt
# Out:
# numpy==2.4.2
# pandas==3.0.1
# python-dateutil==2.9.0.post0
# six==1.17.0

# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')
print('Done')
# Out:
# Done

# %%
ls
# Out:
# feb/  requirements.txt

# %%
df = pd.read_csv('dataset/reviews.csv')

# %%
#Write a program to prompt the user for hours and rate per hour to compute gross pay.

hours = input('Enter hours: ')
rate = input("Enter rate: ")
pay = int(hours) * float(rate)
print('Total income: ',pay)
# Out:
# Enter hours: 3
# Enter rate: 4
# Total income:  12.0

# %%
#width//2 width/2.0 height/3  1 + 2 * 5 */
width = 17
height = 12.0

print('width // 2 =',width//2)
print('width / 2 =',width/2)
print('height / 3 =',height/3)
print('1 + 2 * 5 =',1+2*5)
# Out:
# width // 2 = 8
# width / 2 = 8.5
# height / 3 = 4.0
# 1 + 2 * 5 = 11

# %%
#Write a program that uses input to prompt a user for a number and then outputs the square of the number
number = input('Enter a number: ')
square = int(number) * int(number)
print('the square of',number, 'is',square)
# Out:
# Enter a number: 3
# the square of 3 is 9

# %%
cel = float(input("Enter temperature in Celsius: "))
fc = (cel * 9/5) + 32
print(fc)
# Out:
# Enter temperature in Celsius: 1
# 33.8
