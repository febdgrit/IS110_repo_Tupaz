# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mv "/content/drive/MyDrive/Colab Notebooks/Dashboard.ipynb" "/content/drive/MyDrive/ColabNotebooks/IS110_Bperformance_Tupaz/Dashboard_Tupaz"

# %%
# %cd /content/drive/MyDrive/ColabNotebooks/IS110_Bperformance_Tupaz/Dashboard_Tupaz
# Out:
# /content/drive/MyDrive/ColabNotebooks/IS110_Bperformance_Tupaz/Dashboard_Tupaz

# %%
# !pwd
#for the working directory
# Out:
# /content/drive/MyDrive/ColabNotebooks/IS110_Bperformance_Tupaz/pythonEnvi_Tupaz

# %%
# !pip install virtualenv
# Out:
# Collecting virtualenv
#   Downloading virtualenv-21.2.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting distlib<1,>=0.3.7 (from virtualenv)
#   Downloading distlib-0.4.0-py2.py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: filelock<4,>=3.24.2 in /usr/local/lib/python3.12/dist-packages (from virtualenv) (3.25.2)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /usr/local/lib/python3.12/dist-packages (from virtualenv) (4.9.4)
# Collecting python-discovery>=1 (from virtualenv)
#   Downloading python_discovery-1.2.1-py3-none-any.whl.metadata (5.4 kB)
# Downloading virtualenv-21.2.0-py3-none-any.whl (5.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 26.1 MB/s eta 0:00:00
# Downloading distlib-0.4.0-py2.py3-none-any.whl (469 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 28.6 MB/s eta 0:00:00
# Downloading python_discovery-1.2.1-py3-none-any.whl (31 kB)
# Installing collected packages: distlib, python-discovery, virtualenv
# Successfully installed distlib-0.4.0 python-discovery-1.2.1 virtualenv-21.2.0

# %%
# !virtualenv minealone
# Out:
# created virtual environment CPython3.12.13.final.0-64-x86_64 in 8015ms
#   creator CPython3Posix(dest=/content/drive/MyDrive/ColabNotebooks/IS110_Bperformance_Tupaz/pythonEnvi_Tupaz/minealone, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, via=copy, app_data_dir=/root/.cache/virtualenv)
#     added seed packages: pip==26.0.1
#   activators BashActivator,CShellActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator

# %%
# !source minealone/bin/activate

# %%
# %%writefile practice.txt
# pandas
# numpy
# Out:
# Writing chapter2.txt

# %%
#install the packages in the requirements.txt
# !minealone/bin/pip install -r requirements.txt
# Out:
# Requirement already satisfied: numpy==2.4.2 in ./minealone/lib/python3.12/site-packages (from -r requirements.txt (line 1)) (2.4.2)
# Requirement already satisfied: pandas==3.0.1 in ./minealone/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (3.0.1)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in ./minealone/lib/python3.12/site-packages (from -r requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: six==1.17.0 in ./minealone/lib/python3.12/site-packages (from -r requirements.txt (line 4)) (1.17.0)

# %%
#requirements.txt has been created or updated
# !minealone/bin/pip freeze > requirements.txt

# %%
# !minealone/bin/pip list
# Out:
# Package         Version
# --------------- -----------
# numpy           2.4.2
# pandas          3.0.1
# pip             26.0.1
# python-dateutil 2.9.0.post0
# six             1.17.0

# %%
# !cat requirements.txt
# Out:
# numpy==2.4.2
# pandas==3.0.1
# python-dateutil==2.9.0.post0
# six==1.17.0

# %%
ls
# Out:
# Challenges/  feb/  minealone/  requirements.txt

# %%
import pandas as pd
import numpy as np
import random
from datetime import datetime, timedelta
import plotly.express as px
print('Done')
# Out:
# Done

# %%
np.random.seed(42)
random.seed(42)
first_names = [
    'Zeam' , 'Kyza' , 'Phoenix' , 'Hanni' , 'Feneo' , 'Maria'
]
last_names = [
    'Clarito' , 'Gloria' , 'Ballego' , 'Villa' , 'Abrot' , 'Diesto'
]
address    = ['Cabatuan', 'San Dio', 'St. Barbara', 'Mohon' , 'Maasin' , 'Iloilo']
birthday   = ['January 1 , 2001', 'March 2 , 2001', 'December 3 , 2001', 'April 4 , 2001' , 'July 5 , 2001' , 'September 6 , 2001']

school_id  = ['2023-1234-A','2023-2234-A','2023-3234-A','2023-4234-A','2023-5234-A','2023-6234-A']

# %%
rows = []

for i in range(6):

    first_name = first_names[i % len(first_names)]
    last_name = last_names[i % len(last_names)]
    full_name = f"{first_name} {last_name}"
    address_item = address[i % len(address)] + ", Iloilo"
    bday_item = birthday[i % len(birthday)]
    school_id_item = school_id[i % len(school_id)]
    email = f"{full_name.lower().replace(' ', '.') }@gmail.com"
    rows.append({
        'Name': full_name,
        'Address': address_item,
        'Email': email,
        'Birthday': bday_item,
        'School ID': school_id_item
    })

df = pd.DataFrame(rows) #df is dataframe anykind of name
df.to_csv('student_data.csv', index=False)
print(f'Generated {len(df)} rows -> student_data.csv')
# Out:
# Generated 6 rows -> student_data.csv

# %%
df.head()
# Out:
#               Name              Address                      Email  \
# 0     Zeam Clarito     Cabatuan, Iloilo     zeam.clarito@gmail.com
# 1      Kyza Gloria      San Dio, Iloilo      kyza.gloria@gmail.com
# 2  Phoenix Ballego  St. Barbara, Iloilo  phoenix.ballego@gmail.com
# 3      Hanni Villa        Mohon, Iloilo      hanni.villa@gmail.com
# 4      Feneo Abrot       Maasin, Iloilo      feneo.abrot@gmail.com
#
#             Birthday    School ID
# 0   January 1 , 2001  2023-1234-A
# 1     March 2 , 2001  2023-2234-A
# 2  December 3 , 2001  2023-3234-A
# 3     April 4 , 2001  2023-4234-A
# 4      July 5 , 2001  2023-5234-A

# %%
import plotly.express as px
import pandas as pd

df = pd.read_csv('student_data.csv')

df['Birthday'] = pd.to_datetime(df['Birthday'])
df['Birth_Month'] = df['Birthday'].dt.strftime('%B')

month_counts = df['Birth_Month'].value_counts().reset_index()
month_counts.columns = ['Birth_Month', 'Count']

month_order = ['January', 'February', 'March', 'April', 'May', 'June',
               'July', 'August', 'September', 'October', 'November', 'December']

for month in month_order:
    if month not in month_counts['Birth_Month'].values:
        month_counts = pd.concat([month_counts,
                                  pd.DataFrame({'Birth_Month': [month], 'Count': [0]})],
                                 ignore_index=True)

month_counts = month_counts.set_index('Birth_Month').loc[month_order].reset_index()

fig = px.bar(
    month_counts,
    x='Birth_Month',
    y='Count',
    title='Students by Birth Month',
    labels={'Birth_Month': 'Birth Month', 'Count': 'Number of Students'},
    color='Birth_Month',
    text='Count'
)

fig.update_layout(
    xaxis_title="Birth Month",
    yaxis_title="Number of Students",
    showlegend=False,
    height=500,
    title_x=0.5,
    xaxis={'categoryorder': 'array', 'categoryarray': month_order}
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a5f3527b-e3d0-448f-aa01-1276765325d2" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a5f3527b-e3d0-448f-aa01-1276765325d2")) {                    Plotly.newPlot(                        "a5f3527b-e3d0-448f-aa01-1276765325d2",                        [{"alignmentgroup":"True","hovertemplate":"Birth Month=%{x}\u003cbr\u003eNumber of Students=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"January","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"January","offsetgroup":"January","orientation":"v","showlegend":true,"text":[1.0],"textposition":"auto","x":["January"],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Birth Month=%{x}\u003cbr\u003eNumber of Students=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"February","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"February","offsetgroup":"February","orientation":"v","showlegend":true,"text":[0.0],"textposition":"auto","x":["February"],"xaxis":"x","y":[0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Birth Month=%{x}\u003cbr\u003eNumber of Students=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"March","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"March","offsetgroup":"March","orientation":"v","showlegend":true,"text":[1.0],"textposition":"auto","x":["March"],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Birth Month=%{x}\u003cbr\u003eNumber of Students=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"April","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"April","offsetgroup":"April","orientation":"v","showlegend":true,"text":[1.0],"textposition":"auto","x":["April"],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Birth Month=%{x}\u003cbr\u003eNumber of Students=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"May","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"May","offsetgroup":"May","orientation":"v","showlegend":true,"text":[0.0],"textposition":"auto","x":["May"],"xaxis":"x","y":[0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Birth Month=%{x}\u003cbr\u003eNumber of Students=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"June","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"June","offsetgroup":"June","orientation":"v","showlegend":true,"text":[0.0],"textposition":"auto","x":["June"],"xaxis":"x","y":[0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Birth Month=%{x}\u003cbr\u003eNumber of Students=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"July","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"July","offsetgroup":"July","orientation":"v","showlegend":true,"text":[1.0],"textposition":"auto","x":["July"],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Birth Month=%{x}\u003cbr\u003eNumber of Students=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"August","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"August","offsetgroup":"August","orientation":"v","showlegend":true,"text":[0.0],"textposition":"auto","x":["August"],"xaxis":"x","y":[0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Birth Month=%{x}\u003cbr\u003eNumber of Students=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"September","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"September","offsetgroup":"September","orientation":"v","showlegend":true,"text":[1.0],"textposition":"auto","x":["September"],"xaxis":"x","y":[1], ...
